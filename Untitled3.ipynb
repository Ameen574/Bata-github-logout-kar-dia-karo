# %%
def name(last_name,first_name):
    print(first_name+last_name)
    name(first name="Huzaifa",last name="Kashaf")Z+Z

# %%
elements =[]


while True:


    print("Element in our list:")
    for todoApp in elements:
        print("-->", todoApp)
# Out:
# Element in our list:
# Element in our list:
# Element in our list:
# Element in our list:
# Element in our list:
# Element in our list:
# Element in our list:
# Element in our list:
# Element in our list:
# Element in our list:
# Element in our list:
# Element in our list:
# Element in our list:
# Element in our list:
# Element in our list:
# Element in our list:
# Element in our list:
# Element in our list:
# Element in our list:
# Element in our list:
# Element in our list:
# Element in our list:
# Element in our list:
# Element in our list:
# Element in our list:
# Element in our list:
# Element in our list:
# Element in our list:
# Element in our list:
# Element in our list:
# Element in our list:
# Element in our list:
# Element in our list:
# Element in our list:
# Element in our list:
# Element in our list:
# Element in our list:
# Element in our list:
# Element in our list:
# Element in our list:
# Element in our list:
# Element in our list:
# Element in our list:
# ...
